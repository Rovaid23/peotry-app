# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.utils import pad_sequences

# Load CSV file
data = pd.read_csv('Roman-Urdu-Poetry.csv')

# Filter the first 800 rows for training
data = data.head(800)

# Extract the poetry column
poetry = data['Poetry'].values

# Tokenize the poetry text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(poetry)

# Convert texts to sequences of integers
sequences = tokenizer.texts_to_sequences(poetry)

# Get the maximum sequence length
max_len = max([len(seq) for seq in sequences])

# Pad sequences to have equal length
sequences = pad_sequences(sequences, maxlen=max_len, padding='pre')

# Split the sequences into input (X) and output (y)
X = sequences[:, :-1]  # Input: all words except last
y = sequences[:, -1]   # Output: last word (target)

# Get the vocabulary size
vocab_size = len(tokenizer.word_index) + 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Define the LSTM model
model = Sequential()
model.add(Embedding(input_dim=8386, output_dim=50, input_length=5))  # Explicit shape
model.add(LSTM(128, return_sequences=True))  # First LSTM layer
model.add(LSTM(128))  # Second LSTM layer
model.add(Dense(128, activation='relu'))  # Fully connected layer
model.add(Dense(11044, activation='softmax'))  # Output layer

# Force model to build
model.build(input_shape=(None, 5))  # Explicitly define input shape

# Print model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 5, 50)               │         419,300 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 5, 128)              │          91,648 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 128)                 │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 11044)               │       1,424,676 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,083,720 (7.95 MB)
#  Trainable params: 2,083,720 (7.95 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model and store history
history = model.fit(X, y, epochs=65, batch_size=32, validation_split=0.2)  # 20% data for validation

# Plot accuracy and loss
import matplotlib.pyplot as plt

# Extract values
loss = history.history['loss']
val_loss = history.history.get('val_loss', [])  # Handles case if no validation data
accuracy = history.history.get('accuracy', history.history.get('acc'))  # Handles different versions
val_accuracy = history.history.get('val_accuracy', history.history.get('val_acc', []))

epochs_range = range(1, len(loss) + 1)
# Out:
# Epoch 1/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.6739 - loss: 1.1020 - val_accuracy: 0.6062 - val_loss: 1.3179
# Epoch 2/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.7881 - loss: 0.8594 - val_accuracy: 0.5500 - val_loss: 1.4678
# Epoch 3/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8646 - loss: 0.7537 - val_accuracy: 0.5813 - val_loss: 1.5526
# Epoch 4/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8693 - loss: 0.6853 - val_accuracy: 0.5813 - val_loss: 1.6878
# Epoch 5/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9074 - loss: 0.6471 - val_accuracy: 0.5625 - val_loss: 1.7686
# Epoch 6/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8995 - loss: 0.6113 - val_accuracy: 0.5625 - val_loss: 1.8946
# Epoch 7/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9136 - loss: 0.6058 - val_accuracy: 0.5375 - val_loss: 1.9241
# Epoch 8/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9232 - loss: 0.5154 - val_accuracy: 0.5437 - val_loss: 1.9881
# Epoch 9/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9396 - loss: 0.4540 - val_accuracy: 0.5688 - val_loss: 2.0623
# Epoch 10/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9359 - loss: 0.4519 - val_accuracy: 0.5250 - val_loss: 2.1500
# Epoch 11/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9330 - loss: 0.4385 - val_accuracy: 0.5500 - val_loss: 2.1920
# Epoch 12/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9617 - loss: 0.3957 - val_accuracy: 0.5250 - val_loss: 2.3010
# Epoch 13/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9621 - loss: 0.3575 - val_accuracy: 0.5437 - val_loss: 2.3596
# Epoch 14/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9586 - loss: 0.3508 - val_accuracy: 0.5250 - val_loss: 2.4541
# Epoch 15/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9631 - loss: 0.3307 - val_accuracy: 0.5063 - val_loss: 2.5027
# Epoch 16/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9628 - loss: 0.3210 - val_accuracy: 0.4563 - val_loss: 2.7977
# Epoch 17/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8730 - loss: 0.5275 - val_accuracy: 0.4125 - val_loss: 2.9263
# Epoch 18/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8830 - loss: 0.5128 - val_accuracy: 0.3812 - val_loss: 3.4179
# Epoch 19/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.8104 - loss: 0.6989 - val_accuracy: 0.4000 - val_loss: 3.1758
# Epoch 20/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.8336 - loss: 0.5710 - val_accuracy: 0.4125 - val_loss: 3.1805
# Epoch 21/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9023 - loss: 0.4392 - val_accuracy: 0.3750 - val_loss: 3.0427
# Epoch 22/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9349 - loss: 0.3505 - val_accuracy: 0.4000 - val_loss: 3.2854
# Epoch 23/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9735 - loss: 0.2598 - val_accuracy: 0.4437 - val_loss: 3.3772
# Epoch 24/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9864 - loss: 0.2144 - val_accuracy: 0.4375 - val_loss: 3.3395
# Epoch 25/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9839 - loss: 0.1846 - val_accuracy: 0.4563 - val_loss: 3.3055
# Epoch 26/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9965 - loss: 0.1457 - val_accuracy: 0.4563 - val_loss: 3.3098
# Epoch 27/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9937 - loss: 0.1289 - val_accuracy: 0.4313 - val_loss: 3.3628
# Epoch 28/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9970 - loss: 0.1200 - val_accuracy: 0.4250 - val_loss: 3.4511
# Epoch 29/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9993 - loss: 0.0973 - val_accuracy: 0.4375 - val_loss: 3.5039
# Epoch 30/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9968 - loss: 0.0899 - val_accuracy: 0.4062 - val_loss: 3.5153
# Epoch 31/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 1.0000 - loss: 0.1004 - val_accuracy: 0.4250 - val_loss: 3.5458
# Epoch 32/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9992 - loss: 0.0884 - val_accuracy: 0.4125 - val_loss: 3.5959
# Epoch 33/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9946 - loss: 0.0874 - val_accuracy: 0.3938 - val_loss: 3.6486
# Epoch 34/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9997 - loss: 0.0766 - val_accuracy: 0.4187 - val_loss: 3.6702
# Epoch 35/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9989 - loss: 0.0703 - val_accuracy: 0.4125 - val_loss: 3.6954
# Epoch 36/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9991 - loss: 0.0638 - val_accuracy: 0.4187 - val_loss: 3.7576
# Epoch 37/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 1.0000 - loss: 0.0618 - val_accuracy: 0.4000 - val_loss: 3.7699
# Epoch 38/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9968 - loss: 0.0611 - val_accuracy: 0.4125 - val_loss: 3.8185
# Epoch 39/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.9996 - loss: 0.0473 - val_accuracy: 0.4000 - val_loss: 3.8419
# Epoch 40/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0482 - val_accuracy: 0.4000 - val_loss: 3.8834
# Epoch 41/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9977 - loss: 0.0435 - val_accuracy: 0.4125 - val_loss: 3.9111
# Epoch 42/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9999 - loss: 0.0446 - val_accuracy: 0.4187 - val_loss: 3.9434
# Epoch 43/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0440 - val_accuracy: 0.3938 - val_loss: 3.9675
# Epoch 44/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 1.0000 - loss: 0.0395 - val_accuracy: 0.3938 - val_loss: 4.0190
# Epoch 45/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9997 - loss: 0.0371 - val_accuracy: 0.4062 - val_loss: 4.0137
# Epoch 46/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 1.0000 - loss: 0.0330 - val_accuracy: 0.4062 - val_loss: 4.0652
# Epoch 47/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.3938 - val_loss: 4.0901
# Epoch 48/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0303 - val_accuracy: 0.3938 - val_loss: 4.1133
# Epoch 49/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0317 - val_accuracy: 0.3938 - val_loss: 4.1449
# Epoch 50/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 1.0000 - loss: 0.0269 - val_accuracy: 0.3938 - val_loss: 4.1601
# Epoch 51/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.3750 - val_loss: 4.2039
# Epoch 52/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 1.0000 - loss: 0.0240 - val_accuracy: 0.3875 - val_loss: 4.2243
# Epoch 53/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 1.0000 - loss: 0.0249 - val_accuracy: 0.4000 - val_loss: 4.2464
# Epoch 54/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 1.0000 - loss: 0.0251 - val_accuracy: 0.3875 - val_loss: 4.2814
# Epoch 55/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 1.0000 - loss: 0.0212 - val_accuracy: 0.3875 - val_loss: 4.2951
# Epoch 56/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0220 - val_accuracy: 0.3812 - val_loss: 4.3244
# Epoch 57/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.3938 - val_loss: 4.3303
# Epoch 58/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.3812 - val_loss: 4.3527
# Epoch 59/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 1.0000 - loss: 0.0174 - val_accuracy: 0.3812 - val_loss: 4.3936
# Epoch 60/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 1.0000 - loss: 0.0170 - val_accuracy: 0.3875 - val_loss: 4.3911
# Epoch 61/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 0.3812 - val_loss: 4.4230
# Epoch 62/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.3812 - val_loss: 4.4396
# Epoch 63/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.3875 - val_loss: 4.4519
# Epoch 64/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 1.0000 - loss: 0.0147 - val_accuracy: 0.3875 - val_loss: 4.4920
# Epoch 65/65
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.3812 - val_loss: 4.5037

# %%
import matplotlib.pyplot as plt

# Plot Accuracy Graph
plt.figure(figsize=(8, 5))
plt.plot(history.history['accuracy'], label='Training Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='red')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.title('Model Accuracy Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# Plot Loss Graph
plt.figure(figsize=(8, 5))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='red')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Save the trained model
model.save('poetrymodel.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import numpy as np

def top_k_sampling(pred_probs, k=5):
    """Select the top-k most likely next words and sample from them."""
    top_k_indices = np.argsort(pred_probs)[-k:]  # Get the top k indices
    top_k_probs = pred_probs[top_k_indices]  # Get the corresponding probabilities
    top_k_probs = top_k_probs / np.sum(top_k_probs)  # Normalize to get a valid probability distribution
    return np.random.choice(top_k_indices, p=top_k_probs)  # Sample from top k words

def top_p_sampling(pred_probs, p=0.9):
    """Select the top-p most likely next words (nucleus sampling)."""
    sorted_indices = np.argsort(pred_probs)[::-1]  # Sort probabilities in descending order
    sorted_probs = pred_probs[sorted_indices]
    cumulative_probs = np.cumsum(sorted_probs)

    # Find the cutoff index where the cumulative probability exceeds p
    cutoff_index = np.where(cumulative_probs >= p)[0][0] + 1
    filtered_indices = sorted_indices[:cutoff_index]
    filtered_probs = sorted_probs[:cutoff_index]
    filtered_probs = filtered_probs / np.sum(filtered_probs)  # Normalize to get a valid probability distribution

    return np.random.choice(filtered_indices, p=filtered_probs)  # Sample from top p words

def generate_poetry(model, tokenizer, start_word, num_words_per_line=10, num_lines=3, temperature=1.0, sampling_method='top_k', k=5, p=0.9):
    # Initialize the poem with the starting word and the first line
    poem = start_word
    sequence = tokenizer.texts_to_sequences([start_word])
    sequence = pad_sequences(sequence, maxlen=model.input_shape[1], padding='pre')

    for line_num in range(num_lines):
        # For each line after the first one, don't add the starting word again
        if line_num > 0:
            line = ""  # Start the line without the starting word
        else:
            line = start_word  # First line should start with the starting word

        for _ in range(num_words_per_line - 1):  # Subtract 1 because we already have the first word in the line
            # Predict the next word probabilities
            pred_probs = model.predict(sequence)[0]

            # Apply temperature scaling
            pred_probs = np.asarray(pred_probs).astype('float64')
            pred_probs = np.log(pred_probs) / temperature
            pred_probs = np.exp(pred_probs) / np.sum(np.exp(pred_probs))  # Normalize to get probabilities

            # Apply the selected sampling method
            if sampling_method == 'top_k':
                predicted_word_index = top_k_sampling(pred_probs, k=k)
            elif sampling_method == 'top_p':
                predicted_word_index = top_p_sampling(pred_probs, p=p)
            else:
                # Default to random choice based on probabilities
                predicted_word_index = np.random.choice(range(len(pred_probs)), p=pred_probs)

            predicted_word = tokenizer.index_word.get(predicted_word_index, "")

            if predicted_word == "":  # If the predicted word is empty, break the loop
                break

            line += ' ' + predicted_word

            # Update the sequence with the newly predicted word
            sequence = np.append(sequence[:, 1:], predicted_word_index).reshape(1, -1)

        # Add the generated line to the poem
        poem += '\n' + line

    return poem

# %%
# Prompt the user to enter the starting word, number of words per line, number of lines, and sampling method
start_word = input("Enter the starting word: ")
num_words_per_line = int(input("Enter the number of words per line: "))
num_lines = int(input("Enter the number of lines: "))
temperature = float(input("Enter the temperature (e.g., 0.5 for more creative results): "))
sampling_method = input("Enter the sampling method ('top_k' or 'top_p'): ")

# Set parameters for top-k or top-p sampling
k = 5  # For top-k sampling, the number of words to consider
p = 0.9  # For top-p sampling, the cumulative probability threshold

# Generate the poetry based on the input
generated_poem = generate_poetry(model, tokenizer, start_word, num_words_per_line=num_words_per_line, num_lines=num_lines, temperature=temperature, sampling_method=sampling_method, k=k, p=p)

print("\nGenerated Poetry:\n")
print(generated_poem)
# Out:
# Enter the starting word: 6
# Enter the number of words per line: 7
# Enter the number of lines: 4
# Enter the temperature (e.g., 0.5 for more creative results): 1.2
# Enter the sampling method ('top_k' or 'top_p'): top_k
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# <ipython-input-11-393bb0c41b72>:43: RuntimeWarning: divide by zero encountered in log
#   pred_probs = np.log(pred_probs) / temperature
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
#
# Generated Poetry:
#
# 6
# 6 tan tan saaqī nikleñ bhūleñ ḳhū
#  īl dhīme dhīme dhīme jiye bhūleñ
#  īl dhīme dīz īl dhīme tan
#  hargiz bhūleñ īl bhūleñ tan vaahī
